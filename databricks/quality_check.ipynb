# %%
SILVER_TABLE = "workspace.default.telecom_silver"

df_silver = spark.table(SILVER_TABLE)

row_count = df_silver.count()

if row_count == 0:
    raise Exception("Silver layer is empty!")

print(f"Silver quality check passed! Rows: {row_count}")
